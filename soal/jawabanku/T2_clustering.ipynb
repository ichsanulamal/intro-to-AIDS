# %% [markdown]
# <center>
# <img src="https://drive.google.com/uc?id=1f1gGVI-rxcHjA90WEGNvvtSXF1pAxQwg" alt="Fasilkom UI" width="300"/>
#
# CSGE603130 • Kecerdasan Artifisial dan Sains Data Dasar
#
# Semester Ganjil 2021/2022
#
# Fakultas Ilmu Komputer, Universitas Indonesia
#
# ##**Tugas *2*: *Clustering***
#
# ###**Tenggat Waktu: 12 Oktober 2021, 23.55 WIB**
# </center>
#
# ####**Ketentuan:**
#
# 1. Dataset yang digunakan pada tugas ini beserta deskripsinya telah disediakan di SCeLe.
# 2. Buatlah program Jupyter Notebook yang menjawab pertanyaan sesuai dengan perintah soal yang disediakan.
# 3. Dokumen Jupyter Notebook yang telah dilengkapi dengan jawaban dikumpulkan dengan format penamaan **Kelas_TugasX_NPM_Nama.ipynb**. Contoh: F_Tugas2_1706979341_Lulu Ilmaknun Qurotaini.ipynb
# 4. Kumpulkan dokumen tersebut pada submisi yang telah disediakan di SCeLe sesuai dengan kelas masing-masing sebelum **12 Oktober 2021, 23.55 WIB**. Keterlambatan pengumpulan akan dikenakan pinalti.
# 5. Praktikum ini dirancang sebagai **tugas mandiri**. Plagiarisme tidak diperkenankan dalam bentuk apapun. Adapun kolaborasi berupa diskusi (tanpa menyalin) dan literasi masih diperbolehkan dengan mencantumkan kolaborator dan sumber.

# %% [markdown]
# ## **Pernyataan Integritas**
#
# Wajib diisi. Tanpa pernyataan integritas submisi akan dikenakan pinalti.

# %%
# Isi dengan data diri Anda
NAMA = "Muhammad Ichsanul Amal"
KELAS = "C"
NPM = "1906353454"

# Isi dengan NPM teman yang berdiskusi dengan Anda
KOLABORATOR = []

# Isi dengan sumber referensi yang Anda gunakan dalam mengerjakan
REFERENSI = [
    "ML | Intercluster and Intracluster Distance - GeeksforGeeks. (2019). Retrieved 8 October 2021, from https://www.geeksforgeeks.org/ml-intercluster-and-intracluster-distance/",
    "Why is that K-means algorithm not suitable for classifying elongated data set?. (2021). Retrieved 8 October 2021, from https://www.quora.com/Why-is-that-K-means-algorithm-not-suitable-for-classifying-elongated-data-set",
    "ellipsoids, k. (2011). k-means with ellipsoids. Retrieved 8 October 2021, from https://stackoverflow.com/questions/7880156/k-means-with-ellipsoids",
    "Silhouette Coefficient : Validating clustering techniques. (2020). Retrieved 8 October 2021, from https://towardsdatascience.com/silhouette-coefficient-validating-clustering-techniques-e976bb81d10c",
    "Comparing different hierarchical linkage methods on toy datasets. (2021). Retrieved 8 October 2021, from https://scikit-learn.org/stable/auto_examples/cluster/plot_linkage_comparison.html",
    "https://www.kaggle.com/ruslankl/k-means-clustering-pca"
    "https://stackoverflow.com/questions/46908388/find-euclidean-distance-from-a-point-to-rows-in-pandas-dataframe"
]

# %%
PERNYATAAN_INTEGRITAS = "Saya, %s dari kelas %s dengan NPM %s, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.\n\
Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.\n \
\n\
Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.\n   \
(%s)" % (NAMA, KELAS, NPM, NAMA)

print(PERNYATAAN_INTEGRITAS)
# Out:
# Saya, Muhammad Ichsanul Amal dari kelas C dengan NPM 1906353454, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.
# Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.
#
# Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.
#    (Muhammad Ichsanul Amal)

# %% [markdown]
# ## Soal Tugas 2
# **Catatan**: Algoritma clustering yang boleh dipakai pada tugas ini hanya K-means dan Agglomerative.

# %% [markdown]
# ### Soal 1 [15 Poin] - Teori

# %% [markdown]
# #### a. Jelaskan mengapa K-means clustering tidak cocok untuk yang bukan hyper-spheres?
#
#
# Algoritma K-means bekerja sedemikian sehingga setiap kali dua titik data yang berbeda memiliki jarak yang substansial satu sama lain (meskipun mereka adalah bagian dari kumpulan data yang sama), ia dapat menempatkan mereka ke dalam dua cluster yang berbeda setelah dipartisi. Dengan demikian, K-means cenderung membentuk cluster yang hyper-spheres, yang secara geometris adalah jarak antara setiap dua titik kecil. Tentunya hal itu kurang cocok diterapkan pada yang bukan hyper-spheres. Contoh kurang cocoknya penggunaan K-means clustering dapat dilihat pada nomor 3 bagian d.

# %% [markdown]
# #### b. Jelaskan mengapa algoritma Hierarchical clustering dapat digunakan tanpa perlu menetapkan jumlah cluster?
#
# Algoritma hierarchical clustering dapat bekerja dengan cara agglomerative ataupun divisive. Apabila menggunakan divisive clustering, algoritma tersebut menginisialisasi tree yang mengandung semua titik data, kemudian setiap iterasi, data pada node spesifik dibagi menjadi beberapa beberapa node atau cluster. Sebaliknya, pada agglomerative clustering, algoritma dimulai dari setiap titik pada data, dan dari setiap data tersebut dapat dimerge menjadi cluster baru hingga menjadi hanya satu cluster. Karena kedua algoritma tersebut menyimpan tahapan clusterisasinya, kita tidak perlu menetapkan jumlah cluster di awal, tetapi kita perlu memilih jumlah cluster setelah proses hierarchical clustering selesai.

# %% [markdown]
# #### c. Jelaskan apa itu nilai metrik intra-class similarity dan cara menghitungnya!
#
# Berdasarkan Silhouette Coefficient Formulations, Intra-class similarity merupakan rata-rata jarak antara satu objek dengan objek lainnya pada suatu cluster yang sama. Cara menghitungnya adalah dengan menjumlahkan jarak satu objek tersebut dengan objek lainnya pada cluster, kemudian membaginya dengan jumlah elemen pada cluster. Jarak tiap objek dapat dihitung melalui Complete Diameter Distance, Average Diameter Distance, atau Centroid Diameter Distance. Semakin kecil intra-class similarity, semakin baik pula clustering yang berarti elemen pada cluster sangat mirip.

# %% [markdown]
# #### d. Jelaskan apa itu nilai metrik inter-class similarity dan cara menghitungnya!
#
# Berdasarkan Silhouette Coefficient Formulations, Inter-class similarity merupakan rata-rata jarak antara 1 objek pada satu cluster dengan seluruh objek pada cluster lainnya yang berbeda. Cara menghitungnya adalah dengan menjumlahkan setiap jarak 1 objek tersebut dengan objek lainnya di cluster berbeda, kemudian membaginya dengan banyak elemen pada cluster yang berbeda. Cara menghitung jaraknya bisa melalui Single Linkage Distance, Complete Linkage Distance, Average Linkage Distance, Centroid Linkage Distance, atau Average Centroid Linkage Distance. Semakin besar inter-class similarity semakin baik yang artinya terdapat perbedaan signifikan antara 2 cluster berbeda.

# %% [markdown]
# ### Soal 2 [40 Poin] - Guess the clustering

# %% [markdown]
# #### a. Buka data dari soal2.csv dan plot semua titik di plot dua dimensi!

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
soal2 = pd.read_csv("soal2.csv")
sns.scatterplot(x="x1", y="x2", data=soal2)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# #### b. Dari plot tersebut, usulkan jumlah klaster yang dapat membagi data dengan baik!

# %% [markdown]
# Saya mengusulkan 11 klaster untuk dapat membagi data dengan baik

# %% [markdown]
# #### c. Gunakan sebuah algoritma clustering yang dapat membagi data sesuai dengan jumlah klasteryang Anda usulkan. Jelaskan mengapa algoritma clustering tersebut digunakan!
#
# Terlihat pada visualisasi bahwa tiap titik data tergabung pada suatu cluster yang jelas atau bersifat konvergen. Algoritma K-Means relatif sederhana untuk diimplementasikan dan dapat dengan mudah mengelompokkan data tersebut sehingga saya memilih menggunakannya.

# %%
from sklearn.cluster import KMeans

# %%
# Berikut merupakan Elbow Method untuk mengetahui jumlah cluster yang cocok untuk data soal2.csv
ks = range(5, 15)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(soal2)
    inertias.append(model.inertia_)

plt.figure(figsize=(8,5))
plt.style.use('bmh')
plt.plot(ks, inertias, '-o')
plt.xlabel('Number of clusters, k')
plt.ylabel('Inertia')
plt.xticks(ks)
plt.show()

# %%
kmeans = KMeans(n_clusters=11)
pred_y = kmeans.fit_predict(soal2)

# %% [markdown]
# #### d. Visualisasikan hasil clustering dengan menampilkan scatter plot data yang di color-codedberdasarkan klasternya. Selain itu, cetak jumlah cluster yang dihasilkan!
# **Hint**: Pelajari parameter c pada fungsi matplotlib.pyplot.scatter()

# %%
sns.scatterplot(x="x1", y="x2", data=soal2, c=pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=50, c='red')
plt.show()

# %% [markdown]
# #### e. Hitung nilai intra-class similarity hasil clustering tersebut dengan menghitung jumlah darijarak (sum of distance) masing-masing sampel dengan pusat klasternya! Koordinat sebuah pusat klaster adalah rata-rata dari semua sampel di klaster tersebut. Rumus jarak yang digunakan adalah L2-norm/Euclidean Distance.

# %%
res = soal2.copy()
res["y"] = pred_y

ics = []

print("Rata-rata Intra-class similarity untuk setiap cluster")

pd.DataFrame()

for center in pd.unique(pred_y):
    df_center = res[res["y"] == center]
    x1 = df_center["x1"].mean()
    x2 = df_center["x2"].mean()

    ics_i = (df_center[['x1', 'x2']] - np.array([x1, x2])).pow(2).sum(1).pow(0.5).sum() / (len(df_center)-1)
    ics.append([center, ics_i])

df_result = pd.DataFrame(np.array(ics), columns=["cluster_label", "ics"])
df_result
# Out:
# Rata-rata Intra-class similarity untuk setiap cluster
#     cluster_label       ics
# 0             1.0  0.938146
# 1             9.0  0.924573
# 2             6.0  0.908906
# 3             0.0  1.158484
# 4             7.0  1.539307
# 5             5.0  0.877443
# 6             3.0  1.121818
# 7             8.0  0.850709
# 8             4.0  1.236162
# 9             2.0  0.901749
# 10           10.0  0.927752

# %% [markdown]
# #### f. Hitung nilai silhouette coefficient dari hasil clustering tersebut!

# %%
from sklearn.metrics import silhouette_score
print(f'Silhouette Score(n=11): {silhouette_score(soal2, pred_y)}')
# Out:
# Silhouette Score(n=11): 0.7181806865976839

# %% [markdown]
# ### Soal 3 [30 Poin] - Hierarchical Clustering

# %% [markdown]
# #### a. Buka data dari soal3.csv dan plot semua titik di plot dua dimensi

# %%
soal3 = pd.read_csv("soal3.csv")

sns.scatterplot(x="x", y="y", data=soal3)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# #### b. Pada soal ini, anda diharapkan melakukan clustering menggunakan algoritma Agglomerative sehingga terbuat klaster seperti berikut:
#
# ![temp.png](data:image/png;base64,...)

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc

# %%
plt.figure(figsize =(8, 8))
plt.title('Visualising the data')
Dendrogram = shc.dendrogram((shc.linkage(soal3, method ='ward')))

# %%
ac2 = AgglomerativeClustering(n_clusters = 2, linkage="single")
  
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(soal3['x'], soal3['y'], 
           c = ac2.fit_predict(soal3))
plt.show()

# %% [markdown]
# #### c. Kemungkinan besar saat Anda menggunakan modul algoritma Agglomerative dari library sklearn, Anda harus mengubah parameter yang digunakan. Sebutkan parameter apa saja yang anda gunakan beserta nilainya, dan jelaskan alasan anda menggunakan parameter tersebut dan menggunakan nilai tersebut.

# %% [markdown]
# Paramer yang saya gunakan adalah linkage dengan nilai single yang artinya menggunakan jarak minimum antara semua pengamatan dari dua set. Alasan pemilihan linkage=single adalah karena linkage tersebut dapat bekerja dengan baik pada data non-globular dan tidak ada noise dalam data. Dapat dilihat pada visualisasi, data kedua cluster terpisah dengan rapi dan tidak terlihat noise dari kedua cluster tersebut.

# %% [markdown]
# #### d. (Bonus) Lakukan clustering menggunakan K-Means pada data tersebut, visualisasikan hasilnya, kemudian lakukan analisis terhadap hasil tersebut.

# %% [markdown]
# Dalam hal ini K-Means tidak cocok digunakan karena K-Means menginisiasi 2 sembarang centroid dan yang masuk pada tiap cluster hanyalah titik yang terdekatnya saja. Jadi, meskipun titik-titik pada cluster sebenarnya bukan pada cluster tersebut, apabila dekat, maka K-means tetap mengklasterisasi titik-titik tersebut ke centroid terdekatnya. Berikut visualisasinya

# %%
kmeans = KMeans(n_clusters=2)
pred_y = kmeans.fit_predict(soal3)

sns.scatterplot(x="x", y="y", data=soal3, c = pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=50, c='red')
plt.show()

# %% [markdown]
# ### Soal 4 [20 Poin] - Which came first: dimensionality reduction or clustering?

# %% [markdown]
# #### a. Buka data dari soal4.csv dan tampilkan 10 baris pertama! Hitung jumlah data dan jumlah fitur!

# %%
soal4 = pd.read_csv("soal4.csv")
soal4.head(10)
# Out:
#           A         B         E
# 0  0.470839 -0.978228 -4.981786
# 1 -0.079349 -0.798295 -5.173138
# 2  0.698990 -1.925331 -5.955414
# 3  1.246046 -0.125634 -6.029880
# 4  0.570842 -0.672183 -4.181259
# 5  0.325580 -1.389908 -2.461709
# 6  0.721706 -0.615033 -5.444958
# 7  0.793625 -0.781055 -5.084923
# 8  0.576666  0.001895 -6.165497
# 9  0.907629 -0.650638 -6.290293

# %%
soal4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   E       1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %% [markdown]
# #### b. Ikuti langkah-langkah berikut:

# %% [markdown]
# ##### i. Salin data asli dan masukkan dalam variable data_copy_1!

# %%
data_copy_1 = soal4.copy()

# %% [markdown]
# ##### ii. Lakukan Dimensionality reduction (PCA) pada data_copy_1 sehingga jumlah fiturnya menjadi 2!

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
skl_pca = pca.fit_transform(data_copy_1)
skl_pca.shape
# Out:
# (1000, 2)

# %% [markdown]
# ##### iii. Visualisasikan data_copy_1 yang sudah direduksi, kemudian tentukan berapa jumlah cluster yang tepat!

# %%
principalDf = pd.DataFrame(data = skl_pca
             , columns = ['principal component 1', 'principal component 2'])

fig = plt.figure(figsize = (8,8))

ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

sns.scatterplot(x='principal component 1', y='principal component 2', 
                palette=sns.color_palette("hls", 3),
                cmap='CMRmap', 
                marker='o',
                data=principalDf, 
                )

ax.grid()

# %%
ks = range(1, 10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(principalDf)
    inertias.append(model.inertia_)

plt.figure(figsize=(8,5))
plt.style.use('bmh')
plt.plot(ks, inertias, '-o')
plt.xlabel('Number of clusters, k')
plt.ylabel('Inertia')
plt.xticks(ks)
plt.show()

# %% [markdown]
# Jumlah cluster yang tepat adalah sekitar 2 dan 3

# %% [markdown]
# ##### iv. Lakukan clustering pada data_copy_1 yang sudah direduksi menggunakan K-Means dengan parameter random_state=2021!

# %%
kmeans = KMeans(n_clusters=3, random_state=2021)
pred_y = kmeans.fit_predict(principalDf)

# %% [markdown]
# ##### v. Visualisasikan hasil clustering pada data_copy_1 yang sudah direduksi!

# %%
plt.scatter(principalDf["principal component 1"], principalDf["principal component 2"], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=50, c='red')
plt.show()

# %% [markdown]
# #### c. Ikuti langkah-langkah berikut:

# %% [markdown]
# ##### i. Salin data asli dan masukkan dalam variable data_copy_2!

# %%
data_copy_2 = soal4.copy()

# %% [markdown]
# ##### ii. Lakukan clustering pada data_copy_2 menggunakan K-Means dengan parameter random_state=2021 dan jumlah cluster sama dengan jumlah cluster yang kamu gunakan pada poin b!

# %%
kmeans = KMeans(n_clusters=3, random_state=2021)
pred_y = kmeans.fit_predict(data_copy_2)

# %% [markdown]
# ##### iii. Lakukan Dimensionality reduction (PCA) pada data_copy_2 sehingga jumlah fiturnya menjadi 2!

# %%
pca = PCA(n_components=2)
skl_pca = pca.fit_transform(data_copy_2)

# %% [markdown]
# ##### iv. Visualisasikan hasil clustering pada data_copy_2 yang sudah direduksi!

# %%
plt.scatter(x=skl_pca[:,0], y=skl_pca[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=50, c='red')
plt.show()

# %% [markdown]
# #### d. Apakah ada perbedaan pada hasil poin b dan poin c? Mengapa demikian? Apa kesimpulan yang bisa anda ambil?

# %% [markdown]
# Ya, hasil pada bagian b terlihat lebih jelas perbedaan clusternya. Dapat dilihat juga pada bagian c semua center nya berkumpul di kanan sedangkan pada bagian b lebih dapat dilihat perbedaannya. Alasannya adalah karena pada poin b dilakukan PCA terlebih dahulu sebelum dilakukan clustering menggunakan K-Means. Kesimpulan yang dapat diambil adalah PCA dan K-Means dapat dipadukan sehingga menghasilkan cluster yang lebih baik berdasarkan visualisasi di atas, dan pembagian yang optimal didapatkan setelah menerapkan PCA terlebih dahulu sebelum melakukan clustering.
